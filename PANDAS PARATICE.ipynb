# %% [markdown]
# # fillna
# # isna
# # dropna
# # astype
# # pd.to_datetime
# # df.str.
# # df.dt.
# # group by
# # merge
# # apply (axis=0,axis=1)
# # =====================
# # iterrows
# # pivot_table
# # describe
# # indexing (loc,iloc)
# # conditional subseting (&,|,~)
# # isin
# # query
# # filter
# # transform
# # short values

# %% [markdown]
# #                                  DATAFRAME

# %%
import numpy as np
import pandas as pd

# %%
a=[12,34,56,78,90]
x=pd.DataFrame(a)

# %%
x
# Out:
#     0
# 0  12
# 1  34
# 2  56
# 3  78
# 4  90

# %%
a=[12,34,56,78,90]
x=pd.DataFrame(a,columns=["count"])
x
# Out:
#    count
# 0     12
# 1     34
# 2     56
# 3     78
# 4     90

# %%
a=[12,34,56,78,90]
x=pd.DataFrame(a,columns=["count"],index=["a","b","c","d","e"])
x
# Out:
#    count
# a     12
# b     34
# c     56
# d     78
# e     90

# %%
a=["a","b","c","d"]
b=[9,6,4,7]
x=pd.DataFrame(a,b)
x
# Out:
#    0
# 9  a
# 6  b
# 4  c
# 7  d

# %%
a=["a","b","c","d"]
b=[9,6,4,7]
x=pd.DataFrame(list(zip(a,b)))
x
# Out:
#    0  1
# 0  a  9
# 1  b  6
# 2  c  4
# 3  d  7

# %%
a=["a","b","c","d"]
b=[9,6,4,7]
x=pd.DataFrame(zip(a,b),columns=(["alpha","digit"]),index=(["row1","row2","row3","row4"]))
x
# Out:
#      alpha  digit
# row1     a      9
# row2     b      6
# row3     c      4
# row4     d      7

# %%
d={"a":"Afzal","B":"bhai","c":"chhote"}
x=pd.DataFrame(d,index=([1,2,3,]))
x
# Out:
#        a     B       c
# 1  Afzal  bhai  chhote
# 2  Afzal  bhai  chhote
# 3  Afzal  bhai  chhote

# %% [markdown]
# # by dictonary

# %%
l=["Afzal","Irmul","Arman","Mama"]
l2=[100,200,300,400]
x=pd.DataFrame({"Name":l,"Marks":l2})
x
# Out:
#     Name  Marks
# 0  Afzal    100
# 1  Irmul    200
# 2  Arman    300
# 3   Mama    400

# %%
list1=[100,200,300,400,500]
list2=['ram','kumar','sowjanya','kishna','john']
dict1={"id":list1,"name":list2}
df=pd.DataFrame(dict1)
df
# Out:
#     id      name
# 0  100       ram
# 1  200     kumar
# 2  300  sowjanya
# 3  400    kishna
# 4  500      john

# %%
l=["Afzal","Irmul","Arman","Mama"]
l2=[100,200,300,400]
x=pd.DataFrame({"Name":l,"Marks":l2},index=(["a","b","c","d"]))
x
# Out:
#     Name  Marks
# a  Afzal    100
# b  Irmul    200
# c  Arman    300
# d   Mama    400

# %%
x=np.arange(1,6)
y=pd.DataFrame({"id":x})
y
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %% [markdown]
# # how to rename index column and....

# %%
l=["Afzal","Irmul","Arman","Mama"]
l2=[100,200,300,400]
x=pd.DataFrame(zip(l,l2))
x
# Out:
#        0    1
# 0  Afzal  100
# 1  Irmul  200
# 2  Arman  300
# 3   Mama  400

# %% [markdown]
# ### Default row name and column name is 0 ,1
# ### to change them show below

# %%
l=["Afzal","Irmul","Arman","Mama"]
l2=[100,200,300,400]
x=pd.DataFrame(zip(l,l2),columns=(["name","Marks"]),index=(["a","b","c","d"]))
x
# Out:
#     name  Marks
# a  Afzal    100
# b  Irmul    200
# c  Arman    300
# d   Mama    400

# %% [markdown]
# # another way to change

# %%
#to change columns and index
l=["Afzal","Irmul","Arman","Mama"]
l2=[100,200,300,400]
x=pd.DataFrame(zip(l,l2))
x.columns=["n","m"]
x.index=["a","b","c","d"]
x
# Out:
#        n    m
# a  Afzal  100
# b  Irmul  200
# c  Arman  300
# d   Mama  400

# %%
l=["Afzal","Irmul","Arman","Mama"]
l2=[100,200,300,400]
print("before change")
x=pd.DataFrame(zip(l,l2),columns=(["name","Marks"]),index=(["a","b","c","d"]))
print(x)


print("after change")
x.index=["row1","row2","row3","row4"]
x
# Out:
# before change
#     name  Marks
# a  Afzal    100
# b  Irmul    200
# c  Arman    300
# d   Mama    400
# after change
#        name  Marks
# row1  Afzal    100
# row2  Irmul    200
# row3  Arman    300
# row4   Mama    400

# %% [markdown]
# # how to add columns  and rows

# %% [markdown]
# ### to add columns

# %%
x["fail"]=["yes","no","yes","no"]

# %%
x
# Out:
#        name  Marks fail
# row1  Afzal    100  yes
# row2  Irmul    200   no
# row3  Arman    300  yes
# row4   Mama    400   no

# %% [markdown]
# # another way

# %%
s=[10000,20000,30000,4000]
x["salary"]=s
x
# Out:
#        name  Marks fail  salary
# row1  Afzal    100  yes   10000
# row2  Irmul    200   no   20000
# row3  Arman    300  yes   30000
# row4   Mama    400   no    4000

# %% [markdown]
# # insert column

# %%
x.insert(2, "Age", [21, 23, 24, 21])
x
# Out:
#        name  Marks  Age fail  salary
# row1  Afzal    100   21  yes   10000
# row2  Irmul    200   23   no   20000
# row3  Arman    300   24  yes   30000
# row4   Mama    400   21   no    4000

# %% [markdown]
# # to add in  ROW

# %%
y={"name":"nomi","Marks":500,"Age":50,"fail":"no","salary":100000}
x=x.append(y,ignore_index=True)
x
# Out:
#     name  Marks  Age fail  salary
# 0  Afzal    100   21  yes   10000
# 1  Irmul    200   23   no   20000
# 2  Arman    300   24  yes   30000
# 3   Mama    400   21   no    4000
# 4   nomi    500   50   no  100000

# %%
x.loc[len(x.index)] = ['Amy', 89,20,"no", 93] 
x
# Out:
#     name  Marks  Age fail  salary
# 0  Afzal    100   21  yes   10000
# 1  Irmul    200   23   no   20000
# 2  Arman    300   24  yes   30000
# 3   Mama    400   21   no    4000
# 4   nomi    500   50   no  100000
# 5    Amy     89   20   no      93

# %% [markdown]
# # 1-dimentional data is called as Series
# # 2-dimentional data is called as DataFrame

# %% [markdown]
# # series
# #### always use capital s while writing series

# %%
series1=pd.Series([100,200,300,400])
df=pd.DataFrame(series1,columns=["number"])
df
# Out:
#    number
# 0     100
# 1     200
# 2     300
# 3     400

# %% [markdown]
# # concat

# %% [markdown]
# ##### axis =1,add column wise
# ##### axis=0 add row           seee carefully and absorbe

# %%
s1=pd.Series([100,200,300,400])
s2=pd.Series(["A","Z","d","n"])
df=pd.concat([s1,s2],axis=1)
df
# Out:
#      0  1
# 0  100  A
# 1  200  Z
# 2  300  d
# 3  400  n

# %%
df.columns=["id","name"]
df
# Out:
#     id name
# 0  100    A
# 1  200    Z
# 2  300    d
# 3  400    n

# %%
s1=pd.Series([100,200,300,400])
s2=pd.Series(["A","Z","d","n"])
df=pd.concat([s1,s2],axis=0)
df
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 0      A
# 1      Z
# 2      d
# 3      n
# dtype: object

# %% [markdown]
# # shape

# %%
df
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 0      A
# 1      Z
# 2      d
# 3      n
# dtype: object

# %%
df2.shape
# Out:
# (5000, 14)

# %%
df2.head(1)
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# 0         552             255.28           159.42      140914.56    87999.84
#
#    Total_Profit
# 0      52914.72

# %%
df2[df2.Country=='Antigua and Barbuda'].shape
# Out:
# (0, 14)

# %%
df.shape
# Out:
# (8,)

# %% [markdown]
# # type

# %%
x=np.array([1,2,3,4,5])

# %%
print(x)
# Out:
# [1 2 3 4 5]

# %%
print(type)
# Out:
# <class 'type'>

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
s=pd.Series(x)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
print(type(s))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# creating a series of characters
# notice that the 'dtype' here is 'object'
char_series = pd.Series(['a', 'b', 'af'])
char_series
# Out:
# 0     a
# 1     b
# 2    af
# dtype: object

# %% [markdown]
# # DATE RANGE

# %%
date_series = pd.date_range(start = '11-09-2017', end = '12-12-2017')
date_series
# Out:
# DatetimeIndex(['2017-11-09', '2017-11-10', '2017-11-11', '2017-11-12',
#                '2017-11-13', '2017-11-14', '2017-11-15', '2017-11-16',
#                '2017-11-17', '2017-11-18', '2017-11-19', '2017-11-20',
#                '2017-11-21', '2017-11-22', '2017-11-23', '2017-11-24',
#                '2017-11-25', '2017-11-26', '2017-11-27', '2017-11-28',
#                '2017-11-29', '2017-11-30', '2017-12-01', '2017-12-02',
#                '2017-12-03', '2017-12-04', '2017-12-05', '2017-12-06',
#                '2017-12-07', '2017-12-08', '2017-12-09', '2017-12-10',
#                '2017-12-11', '2017-12-12'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # selicing

# %%
s = pd.Series([10,20,30,46,7])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    46
# 4     7
# dtype: int64

# %%
s[0]
# Out:
# 10

# %%
s[2:4]
# Out:
# 2    30
# 3    46
# dtype: int64

# %%
s[[1,4]]
# Out:
# 1    20
# 4     7
# dtype: int64

# %% [markdown]
# # uploading file

# %%
x=pd.read_csv("Titanic.csv")
df=pd.read_excel("loandata.xlsx")

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001722    Male     Yes          0      Graduate            No
# 1   LP002502  Female     Yes          2  Not Graduate           NaN
# 2   LP002949  Female      No         3+      Graduate           NaN
# 3   LP002603  Female      No          0      Graduate            No
# 4   LP001644     NaN     Yes          0      Graduate           Yes
# 5   LP001259    Male     Yes          1      Graduate           Yes
# 6   LP002345    Male     Yes          0      Graduate            No
# 7   LP002717    Male     Yes          0      Graduate            No
# 8   LP001030    Male     Yes          2      Graduate            No
# 9   LP001267  Female     Yes          2      Graduate            No
# 10  LP001086    Male      No          0  Not Graduate            No
# 11  LP002287  Female      No          0      Graduate            No
# 12  LP001518    Male     Yes          1      Graduate            No
# ...

# %%
df.tail()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 609  LP001640   Male     Yes          0  Graduate           Yes
# 610  LP001536   Male     Yes         3+  Graduate            No
# 611  LP001585    NaN     Yes         3+  Graduate            No
# 612  LP002101   Male     Yes          0  Graduate           NaN
# 613  LP002317   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609            39147             4750.0       120.0             360.0
# 610            39999                0.0       600.0             180.0
# 611            51763                0.0       700.0             300.0
# 612            63337                0.0       490.0             180.0
# 613            81000                0.0       360.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0     Semiurban           Y
# 610             0.0     Semiurban           Y
# ...

# %%
df.tail(10)
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 604  LP001922   Male     Yes          0  Graduate            No
# 605  LP002624   Male     Yes          0  Graduate            No
# 606  LP001448    NaN     Yes         3+  Graduate            No
# 607  LP001637   Male     Yes          1  Graduate            No
# 608  LP002422   Male      No          1  Graduate            No
# 609  LP001640   Male     Yes          0  Graduate           Yes
# 610  LP001536   Male     Yes         3+  Graduate            No
# 611  LP001585    NaN     Yes         3+  Graduate            No
# 612  LP002101   Male     Yes          0  Graduate           NaN
# 613  LP002317   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            20667                0.0         NaN             360.0
# 605            20833             6667.0       480.0             360.0
# ...

# %% [markdown]
# ### info() to find the details
# ### head to show
# ### tail to show last
# ### describe to show mean ....
# ### dtype to see the data types
# ### count(),value_counts()
# ### show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.count()
# Out:
# Loan_ID              614
# Gender               601
# Married              611
# Dependents           599
# Education            614
# Self_Employed        582
# ApplicantIncome      614
# CoapplicantIncome    614
# LoanAmount           592
# Loan_Amount_Term     600
# Credit_History       564
# Property_Area        614
# Loan_Status          614
# dtype: int64

# %%
df["Married"].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df['LoanAmount'].value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 62.0      1
# 142.0     1
# 239.0     1
# 42.0      1
# 360.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %% [markdown]
# # max,min,mean ,madian

# %%
df.max()
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# Loan_ID                  LP002990
# Education            Not Graduate
# ApplicantIncome             81000
# CoapplicantIncome         41667.0
# LoanAmount                  700.0
# Loan_Amount_Term            480.0
# Credit_History                1.0
# Property_Area               Urban
# Loan_Status                     Y
# dtype: object

# %%
df["ApplicantIncome"].max()
# Out:
# 81000

# %%
df["ApplicantIncome"].min()
# Out:
# 150

# %%
df["ApplicantIncome"].mean()
# Out:
# 5403.459283387622

# %%
df["ApplicantIncome"].median()
# Out:
# 3812.5

# %% [markdown]
# # important

# %%
df.describe(include = ['O'])
# Out:
#          Loan_ID Gender Married  Dependents Education Self_Employed  \
# count        614    601     611         599       614           582
# unique       614      2       2           4         2             2
# top     LP001722   Male     Yes           0  Graduate            No
# freq           1    489     398         345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %% [markdown]
# # null()
# ###### to check how many null value is there

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ###### to find percentage

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %% [markdown]
# # TYPE CONVERSTION

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df["ApplicantIncome"]=df["ApplicantIncome"].astype(str)
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome       object
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df = df.astype({'CoapplicantIncome':'int'})
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome       object
# CoapplicantIncome      int32
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df["LoanAmount"]=df["LoanAmount"].astype(int)
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10264/414542574.py in <module>
# ----> 1 df["LoanAmount"]=df["LoanAmount"].astype(int)
#       2 df.dtypes
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df1=pd.read_csv("Sales_Data.csv")
df1.dtypes
# Out:
# Region                object
# Country               object
# Item_Type             object
# Sales_Channel         object
# Order_Priority        object
# Order_Date            object
# Order_ID             float64
# Ship_Date             object
# Units_Sold             int64
# Unit_SellingPrice    float64
# Unit_MakingCost      float64
# Total_Revenue        float64
# Total_Cost           float64
# Total_Profit         float64
# dtype: object

# %%
df1.head(2)
# Out:
#                               Region               Country  Item_Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
#
#   Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# 0        Online              M  12/20/2013  957081544.0  01-11-2014
# 1       Offline              C  07-05-2010  301644504.0   7/26/2010
#
#    Units_Sold  Unit_SellingPrice  Unit_MakingCost  Total_Revenue  Total_Cost  \
# 0         552             255.28           159.42      140914.56    87999.84
# 1        2167             152.58            97.44      330640.86   211152.48
#
#    Total_Profit
# 0      52914.72
# 1     119488.38

# %% [markdown]
# # to convert datetime

# %%
df1["Order_Date"]=pd.to_datetime(df1["Order_Date"])

# %%
df1.dtypes
# Out:
# Region                       object
# Country                      object
# Item_Type                    object
# Sales_Channel                object
# Order_Priority               object
# Order_Date           datetime64[ns]
# Order_ID                    float64
# Ship_Date                    object
# Units_Sold                    int64
# Unit_SellingPrice           float64
# Unit_MakingCost             float64
# Total_Revenue               float64
# Total_Cost                  float64
# Total_Profit                float64
# dtype: object

# %% [markdown]
# # to find specific column

# %%
df["Loan_ID"]
# Out:
# 0      LP001722
# 1      LP002502
# 2      LP002949
# 3      LP002603
# 4      LP001644
#          ...
# 609    LP001640
# 610    LP001536
# 611    LP001585
# 612    LP002101
# 613    LP002317
# Name: Loan_ID, Length: 614, dtype: object

# %%
df["Gender"]=="Male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 609     True
# 610     True
# 611    False
# 612     True
# 613     True
# Name: Gender, Length: 614, dtype: bool

# %%
df.Dependents
# Out:
# 0       0
# 1       2
# 2      3+
# 3       0
# 4       0
#        ..
# 609     0
# 610    3+
# 611    3+
# 612     0
# 613    3+
# Name: Dependents, Length: 614, dtype: object

# %%
df["Property_Area"]
# Out:
# 0          Rural
# 1      Semiurban
# 2          Urban
# 3          Rural
# 4          Rural
#          ...
# 609    Semiurban
# 610    Semiurban
# 611        Urban
# 612        Urban
# 613        Rural
# Name: Property_Area, Length: 614, dtype: object

# %% [markdown]
# # conditional subseting (&,|,~)

# %%
df[df["Gender"]=="Female"]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 9    LP001267  Female     Yes          2      Graduate            No
# 11   LP002287  Female      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 585  LP001516  Female     Yes          2      Graduate            No
# 589  LP002194  Female      No          0      Graduate           Yes
# 596  LP002582  Female      No          0  Not Graduate           Yes
# 598  LP002731  Female      No          0  Not Graduate           Yes
# 600  LP002813  Female     Yes          1      Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df[(df.Gender=="Male") & (df.Married=="Yes")]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001722   Male     Yes          0  Graduate            No
# 5    LP001259   Male     Yes          1  Graduate           Yes
# 6    LP002345   Male     Yes          0  Graduate            No
# 7    LP002717   Male     Yes          0  Graduate            No
# 8    LP001030   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 607  LP001637   Male     Yes          1  Graduate            No
# 609  LP001640   Male     Yes          0  Graduate           Yes
# 610  LP001536   Male     Yes         3+  Graduate            No
# 612  LP002101   Male     Yes          0  Graduate           NaN
# 613  LP002317   Male     Yes         3+  Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               150               1800       135.0             360.0
# ...

# %%
df[~(df.Gender=="Male") & (df.Married=="Yes")].head()
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1   LP002502  Female     Yes          2  Not Graduate           NaN
# 4   LP001644     NaN     Yes          0      Graduate           Yes
# 9   LP001267  Female     Yes          2      Graduate            No
# 34  LP001155  Female     Yes          0  Not Graduate            No
# 43  LP002670  Female     Yes          2      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1              210               2917        98.0             360.0
# 4              674               5296       168.0             360.0
# 9             1378               1881       167.0             360.0
# 34            1928               1644       100.0             360.0
# 43            2031               1632       113.0             480.0
#
#     Credit_History Property_Area Loan_Status
# 1              1.0     Semiurban           Y
# 4              1.0         Rural           Y
# ...

# %%
(df.Education=="Graduate")&(df.Self_Employed=="Yes")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 609     True
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 614, dtype: bool

# %%
x=df[~(df.Education=="Graduate")&(df.Self_Employed=="Yes")]# u will get non graduate
x.head()
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 29   LP001245   Male     Yes          2  Not Graduate           Yes
# 114  LP001841   Male      No          0  Not Graduate           Yes
# 123  LP001207   Male     Yes          0  Not Graduate           Yes
# 145  LP002444   Male      No          1  Not Graduate           Yes
# 231  LP001264   Male     Yes         3+  Not Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 29             1875               1875        97.0             360.0
# 114            2583               2167       104.0             360.0
# 123            2609               3449       165.0             180.0
# 145            2769               1542       190.0             360.0
# 231            3333               2166       130.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 29              1.0     Semiurban           Y
# 114             1.0         Rural           Y
# ...

# %%
df[~((df.Education=="Graduate")&(df.Self_Employed=="Yes"))].head()# u will get non graduate and non employed
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 6  LP002345    Male     Yes          0      Graduate            No
#
#   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             150               1800       135.0             360.0
# 1             210               2917        98.0             360.0
# 2             416              41667       350.0             180.0
# 3             645               3683       113.0             480.0
# 6            1025               2773       112.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df2=pd.read_csv("Titanic.csv")

# %%
df2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df2[(df2.Fare>100)].head()
# Out:
#     PassengerId  Pclass                                             Name  \
# 24          916       1  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 53          945       1                       Fortune, Miss. Ethel Flora
# 59          951       1                      Chaudanson, Miss. Victorine
# 64          956       1                      Ryerson, Master. John Borie
# 69          961       1              Fortune, Mrs. Mark (Mary McDougald)
#
#        Sex   Age  SibSp  Parch    Ticket     Fare            Cabin Embarked
# 24  female  48.0      1      3  PC 17608  262.375  B57 B59 B63 B66        C
# 53  female  28.0      3      2     19950  263.000      C23 C25 C27        S
# 59  female  36.0      0      0  PC 17608  262.375              B61        C
# 64    male  13.0      2      2  PC 17608  262.375  B57 B59 B63 B66        C
# 69  female  60.0      1      4     19950  263.000      C23 C25 C27        S

# %%
df2[(df2.Fare==45)|(df2.Parch==3)]
# Out:
#      PassengerId  Pclass                                              Name  \
# 24           916       1   Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 142         1034       1                        Ryerson, Mr. Arthur Larned
# 178         1070       2  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
#
#         Sex   Age  SibSp  Parch    Ticket     Fare            Cabin Embarked
# 24   female  48.0      1      3  PC 17608  262.375  B57 B59 B63 B66        C
# 142    male  61.0      1      3  PC 17608  262.375  B57 B59 B63 B66        C
# 178  female  36.0      0      3    230136   39.000               F4        S

# %% [markdown]
# # sort

# %%
df.groupby('Sex')['Fare'].mean()
# Out:
# Sex
# female    49.747699
# male      27.527877
# Name: Fare, dtype: float64

# %%
df.groupby('Sex')['Fare'].mean().sort_values(ascending=False)
# Out:
# Sex
# female    49.747699
# male      27.527877
# Name: Fare, dtype: float64

# %%
df2.sort_values(["Age"])
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 250         1142       2                    West, Miss. Barbara J  female
# ..           ...     ...                                      ...     ...
# 408         1300       3          Riordan, Miss. Johanna Hannah""  female
# 410         1302       3                   Naughton, Miss. Hannah  female
# 413         1305       3                       Spector, Mr. Woolf    male
# 416         1308       3                      Ware, Mr. Frederick    male
# 417         1309       3                 Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
df2.sort_values(["Pclass","Parch"])
# Out:
#      PassengerId  Pclass                                               Name  \
# 11           903       1                         Jones, Mr. Charles Cresson
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 20           912       1                             Rothschild, Mr. Martin
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# ..           ...     ...                                                ...
# 132         1024       3                      Lefebre, Mrs. Frank (Frances)
# 174         1066       3         Asplund, Mr. Carl Oscar Vilhelm Gustafsson
# 139         1031       3                     Goodwin, Mr. Charles Frederick
# 342         1234       3                              Sage, Mr. John George
# 365         1257       3                     Sage, Mrs. John (Annie Bullen)
#
# ...

# %% [markdown]
# ### for desanding

# %%
df2.sort_values(["Age"],ascending=False)
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %% [markdown]
# # sort based on multiple columns

# %%
df2.sort_values(["Age","Fare"],ascending=[False,True]) # when age is same then see the fare column
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 236         1128       1                           Warren, Mr. Frank Manley
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# ..           ...     ...                                                ...
# 146         1038       1                        Hilliard, Mr. Herbert Henry
# 39           931       3                                      Hee, Mr. Ling
# 188         1080       3                                    Sage, Miss. Ada
# 342         1234       3                              Sage, Mr. John George
# 365         1257       3                     Sage, Mrs. John (Annie Bullen)
#
# ...

# %%
df2.sort_values(["Age","Fare"],ascending=[True,True]).head() # when age is same then see the fare column
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 250         1142       2                    West, Miss. Barbara J  female
#
#       Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 354  0.17      1      2           C.A. 2315  20.575   NaN        S
# 201  0.33      0      2              347080  14.400   NaN        S
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.775   NaN        S
# 307  0.83      0      1              392091   9.350   NaN        S
# 250  0.92      1      2          C.A. 34651  27.750   NaN        S

# %% [markdown]
# # columns

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %% [markdown]
# # rename columns name

# %%
df2.rename(columns={"Gender":"sex"})
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df2.rename(columns={'Fare':'Cost','Pclass':'Class'},inplace=True)
df2.head()
# Out:
#    PassengerId  Class                                          Name     Sex  \
# 0          892      3                              Kelly, Mr. James    male
# 1          893      3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894      2                     Myles, Mr. Thomas Francis    male
# 3          895      3                              Wirz, Mr. Albert    male
# 4          896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Cost Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # copy and deepcopy

# %%
x=df.copy()

# %%
x
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df4=df.copy(deep=True)
df4.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             150               1800       135.0             360.0
# 1             210               2917        98.0             360.0
# 2             416              41667       350.0             180.0
# 3             645               3683       113.0             480.0
# 4             674               5296       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %% [markdown]
# # delete and drop

# %%
del x["Gender"] # dont touch the orignal dataframe

# %%
x.head() # you can see "Gender is delected" from x but not from df this is the benifit of copy
# Out:
#     Loan_ID Married Dependents     Education Self_Employed ApplicantIncome  \
# 0  LP001722     Yes          0      Graduate            No             150
# 1  LP002502     Yes          2  Not Graduate           NaN             210
# 2  LP002949      No         3+      Graduate           NaN             416
# 3  LP002603      No          0      Graduate            No             645
# 4  LP001644     Yes          0      Graduate           Yes             674
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0               1800       135.0             360.0             1.0
# 1               2917        98.0             360.0             1.0
# 2              41667       350.0             180.0             NaN
# 3               3683       113.0             480.0             1.0
# 4               5296       168.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1     Semiurban           Y
# ...

# %%
df.drop("Married",axis=1)
# Out:
#       Loan_ID  Gender Dependents     Education Self_Employed ApplicantIncome  \
# 0    LP001722    Male          0      Graduate            No             150
# 1    LP002502  Female          2  Not Graduate           NaN             210
# 2    LP002949  Female         3+      Graduate           NaN             416
# 3    LP002603  Female          0      Graduate            No             645
# 4    LP001644     NaN          0      Graduate           Yes             674
# ..        ...     ...        ...           ...           ...             ...
# 609  LP001640    Male          0      Graduate           Yes           39147
# 610  LP001536    Male         3+      Graduate            No           39999
# 611  LP001585     NaN         3+      Graduate            No           51763
# 612  LP002101    Male          0      Graduate           NaN           63337
# 613  LP002317    Male         3+      Graduate            No           81000
#
# ...

# %%
df.head(2) # u can still see "Married column "
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
#
#   ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             150               1800       135.0             360.0
# 1             210               2917        98.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y

# %%
df=pd.read_excel("loandata.xlsx")

# %%
df.drop("Married",axis=1,inplace=True)# use inplace=True or assign to new df
df
# Out:
#       Loan_ID  Gender Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001722    Male          0      Graduate            No              150
# 1    LP002502  Female          2  Not Graduate           NaN              210
# 2    LP002949  Female         3+      Graduate           NaN              416
# 3    LP002603  Female          0      Graduate            No              645
# 4    LP001644     NaN          0      Graduate           Yes              674
# ..        ...     ...        ...           ...           ...              ...
# 609  LP001640    Male          0      Graduate           Yes            39147
# 610  LP001536    Male         3+      Graduate            No            39999
# 611  LP001585     NaN         3+      Graduate            No            51763
# 612  LP002101    Male          0      Graduate           NaN            63337
# 613  LP002317    Male         3+      Graduate            No            81000
#
# ...

# %% [markdown]
# # for multiple columns

# %%
df.drop(["Property_Area","LoanAmount"],axis=1,inplace=True)# use inplace=True or assign to new df
df
# Out:
#       Loan_ID  Gender Dependents     Education Self_Employed  ApplicantIncome  \
# 0    LP001722    Male          0      Graduate            No              150
# 1    LP002502  Female          2  Not Graduate           NaN              210
# 2    LP002949  Female         3+      Graduate           NaN              416
# 3    LP002603  Female          0      Graduate            No              645
# 4    LP001644     NaN          0      Graduate           Yes              674
# ..        ...     ...        ...           ...           ...              ...
# 609  LP001640    Male          0      Graduate           Yes            39147
# 610  LP001536    Male         3+      Graduate            No            39999
# 611  LP001585     NaN         3+      Graduate            No            51763
# 612  LP002101    Male          0      Graduate           NaN            63337
# 613  LP002317    Male         3+      Graduate            No            81000
#
# ...

# %% [markdown]
# # del rows

# %%
df.drop(0,axis=0)
# Out:
#       Loan_ID  Gender Dependents     Education Self_Employed  ApplicantIncome  \
# 1    LP002502  Female          2  Not Graduate           NaN              210
# 2    LP002949  Female         3+      Graduate           NaN              416
# 3    LP002603  Female          0      Graduate            No              645
# 4    LP001644     NaN          0      Graduate           Yes              674
# 5    LP001259    Male          1      Graduate           Yes             1000
# ..        ...     ...        ...           ...           ...              ...
# 609  LP001640    Male          0      Graduate           Yes            39147
# 610  LP001536    Male         3+      Graduate            No            39999
# 611  LP001585     NaN         3+      Graduate            No            51763
# 612  LP002101    Male          0      Graduate           NaN            63337
# 613  LP002317    Male         3+      Graduate            No            81000
#
# ...

# %% [markdown]
# # for multiple rows

# %%
df.drop([5,7,9],axis=0).head(10)
# Out:
#      Loan_ID  Gender Dependents     Education Self_Employed  ApplicantIncome  \
# 0   LP001722    Male          0      Graduate            No              150
# 1   LP002502  Female          2  Not Graduate           NaN              210
# 2   LP002949  Female         3+      Graduate           NaN              416
# 3   LP002603  Female          0      Graduate            No              645
# 4   LP001644     NaN          0      Graduate           Yes              674
# 6   LP002345    Male          0      Graduate            No             1025
# 8   LP001030    Male          2      Graduate            No             1299
# 10  LP001086    Male          0  Not Graduate            No             1442
# 11  LP002287  Female          0      Graduate            No             1500
# 12  LP001518    Male          1      Graduate            No             1538
#
#     CoapplicantIncome  Loan_Amount_Term  Credit_History Loan_Status
# ...

# %% [markdown]
# # insert &add columns

# %%
df.insert(4,"column",np.nan)
df
# Out:
#       Loan_ID  Gender Dependents     Education  column Self_Employed  \
# 0    LP001722    Male          0      Graduate     NaN            No
# 1    LP002502  Female          2  Not Graduate     NaN           NaN
# 2    LP002949  Female         3+      Graduate     NaN           NaN
# 3    LP002603  Female          0      Graduate     NaN            No
# 4    LP001644     NaN          0      Graduate     NaN           Yes
# ..        ...     ...        ...           ...     ...           ...
# 609  LP001640    Male          0      Graduate     NaN           Yes
# 610  LP001536    Male         3+      Graduate     NaN            No
# 611  LP001585     NaN         3+      Graduate     NaN            No
# 612  LP002101    Male          0      Graduate     NaN           NaN
# 613  LP002317    Male         3+      Graduate     NaN            No
#
#      ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# ...

# %%
df["hello"]=np.nan

# %%
df.head()
# Out:
#     Loan_ID  Gender Dependents     Education  column Self_Employed  \
# 0  LP001722    Male          0      Graduate     NaN            No
# 1  LP002502  Female          2  Not Graduate     NaN           NaN
# 2  LP002949  Female         3+      Graduate     NaN           NaN
# 3  LP002603  Female          0      Graduate     NaN            No
# 4  LP001644     NaN          0      Graduate     NaN           Yes
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0              150             1800.0             360.0             1.0
# 1              210             2917.0             360.0             1.0
# 2              416            41667.0             180.0             NaN
# 3              645             3683.0             480.0             1.0
# 4              674             5296.0             360.0             1.0
#
#   Loan_Status  hello
# 0           N    NaN
# 1           Y    NaN
# 2           N    NaN
# 3           Y    NaN
# ...

# %%
df["useless"]="Afzal"

# %%
df.head()
# Out:
#     Loan_ID  Gender Dependents     Education  column Self_Employed  \
# 0  LP001722    Male          0      Graduate     NaN            No
# 1  LP002502  Female          2  Not Graduate     NaN           NaN
# 2  LP002949  Female         3+      Graduate     NaN           NaN
# 3  LP002603  Female          0      Graduate     NaN            No
# 4  LP001644     NaN          0      Graduate     NaN           Yes
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0              150             1800.0             360.0             1.0
# 1              210             2917.0             360.0             1.0
# 2              416            41667.0             180.0             NaN
# 3              645             3683.0             480.0             1.0
# 4              674             5296.0             360.0             1.0
#
#   Loan_Status  hello useless
# 0           N    NaN   Afzal
# 1           Y    NaN   Afzal
# 2           N    NaN   Afzal
# ...

# %%
df=pd.read_csv("Titanic.csv")
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df["total_fare"]=df["SibSp"]*df["Parch"]
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # to find index no

# %%
df1[df.Loan_Amount_Term==360].index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10264/93748180.py in <module>
# ----> 1 df1[df.Loan_Amount_Term==360].index
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Loan_Amount_Term'

# %%
## df.drop(df[df.Loan_Amount_Term==360].index)

# %% [markdown]
# # indexing (loc,iloc)¶

# %%
df=pd.read_csv("Titanic.csv")
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.loc[0]
# Out:
# PassengerId                 892
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
df.loc[5]
# Out:
# PassengerId                           897
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                  14.0
# SibSp                                   0
# Parch                                   0
# Ticket                               7538
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 5, dtype: object

# %%
df.iloc[0]
# Out:
# PassengerId                 892
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
df.iloc[0,0]
# Out:
# 892

# %%
df.iloc[0,1]
# Out:
# 3

# %%
df.iloc[1,3]
# Out:
# 'female'

# %%
df.iloc[0:2]
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S

# %%
df.loc[0:2]
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
df.iloc[0:3,0:2]
# Out:
#    PassengerId  Pclass
# 0          892       3
# 1          893       3
# 2          894       2

# %%
df.loc[2,"Name"]
# Out:
# 'Myles, Mr. Thomas Francis'

# %%
df.loc[2:5,["Name","Sex"]]
# Out:
#                                            Name     Sex
# 2                     Myles, Mr. Thomas Francis    male
# 3                              Wirz, Mr. Albert    male
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                    Svensson, Mr. Johan Cervin    male

# %%
df=pd.read_excel("loandata.xlsx")

# %%
df.loc[0:2,"Gender"]
# Out:
# 0      Male
# 1    Female
# 2    Female
# Name: Gender, dtype: object

# %%
df.loc[ 0:3, ["Loan_ID","ApplicantIncome","CoapplicantIncome"]]
# Out:
#     Loan_ID  ApplicantIncome  CoapplicantIncome
# 0  LP001722              150             1800.0
# 1  LP002502              210             2917.0
# 2  LP002949              416            41667.0
# 3  LP002603              645             3683.0

# %%
df.iloc[: , [0,6,7]]
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome
# 0    LP001722              150             1800.0
# 1    LP002502              210             2917.0
# 2    LP002949              416            41667.0
# 3    LP002603              645             3683.0
# 4    LP001644              674             5296.0
# ..        ...              ...                ...
# 609  LP001640            39147             4750.0
# 610  LP001536            39999                0.0
# 611  LP001585            51763                0.0
# 612  LP002101            63337                0.0
# 613  LP002317            81000                0.0
#
# [614 rows x 3 columns]

# %%
df[["Loan_ID","ApplicantIncome","CoapplicantIncome"]]
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome
# 0    LP001722              150             1800.0
# 1    LP002502              210             2917.0
# 2    LP002949              416            41667.0
# 3    LP002603              645             3683.0
# 4    LP001644              674             5296.0
# ..        ...              ...                ...
# 609  LP001640            39147             4750.0
# 610  LP001536            39999                0.0
# 611  LP001585            51763                0.0
# 612  LP002101            63337                0.0
# 613  LP002317            81000                0.0
#
# [614 rows x 3 columns]

# %%
df["Loan_ID"]
# Out:
# 0      LP001722
# 1      LP002502
# 2      LP002949
# 3      LP002603
# 4      LP001644
#          ...
# 609    LP001640
# 610    LP001536
# 611    LP001585
# 612    LP002101
# 613    LP002317
# Name: Loan_ID, Length: 614, dtype: object

# %% [markdown]
# # row selaction

# %%
df.iloc[3]
# Out:
# Loan_ID              LP002603
# Gender                 Female
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome           645
# CoapplicantIncome      3683.0
# LoanAmount              113.0
# Loan_Amount_Term        480.0
# Credit_History            1.0
# Property_Area           Rural
# Loan_Status                 Y
# Name: 3, dtype: object

# %%
df.iloc[1:4]
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0     Semiurban           Y
# 2             NaN         Urban           N
# 3             1.0         Rural           Y

# %% [markdown]
# # indvisual raw selaction

# %%
df.iloc[[3]]
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 3  LP002603  Female      No          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 3              645             3683.0       113.0             480.0
#
#    Credit_History Property_Area Loan_Status
# 3             1.0         Rural           Y

# %%
df.iloc[[3,6]]
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 3  LP002603  Female      No          0  Graduate            No
# 6  LP002345    Male     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 3              645             3683.0       113.0             480.0
# 6             1025             2773.0       112.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 3             1.0         Rural           Y
# 6             1.0         Rural           Y

# %% [markdown]
# # multiple columns

# %%
## multiple columns

df3 = df[['Gender','Married']]
df3
# Out:
#      Gender Married
# 0      Male     Yes
# 1    Female     Yes
# 2    Female      No
# 3    Female      No
# 4       NaN     Yes
# ..      ...     ...
# 609    Male     Yes
# 610    Male     Yes
# 611     NaN     Yes
# 612    Male     Yes
# 613    Male     Yes
#
# [614 rows x 2 columns]

# %%
df3 = df.loc[df["Gender"] == "Male",["Loan_ID","Gender"]]
df3.head()
# Out:
#     Loan_ID Gender
# 0  LP001722   Male
# 5  LP001259   Male
# 6  LP002345   Male
# 7  LP002717   Male
# 8  LP001030   Male

# %%
df3=df.loc[df["ApplicantIncome"]<1500 , ]
df3.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        11.000000          11.000000   11.000000         11.000000
# mean        842.181818        6329.545455  138.272727        332.727273
# std         455.508906       11834.673002   90.394791         98.090867
# min         150.000000           0.000000   17.000000        120.000000
# 25%         530.500000        1840.500000  104.000000        360.000000
# 50%        1000.000000        2917.000000  113.000000        360.000000
# 75%        1162.000000        4489.500000  167.500000        360.000000
# max        1442.000000       41667.000000  350.000000        480.000000
#
#        Credit_History
# count             9.0
# mean              1.0
# std               0.0
# min               1.0
# 25%               1.0
# 50%               1.0
# 75%               1.0
# max               1.0

# %%
df2 = df.loc[df["Gender"] == "Male"  ,  ["Gender","Married","Dependents"]]
df2.tail()
# Out:
#     Gender Married Dependents
# 608   Male      No          1
# 609   Male     Yes          0
# 610   Male     Yes         3+
# 612   Male     Yes          0
# 613   Male     Yes         3+

# %%
df3 = df.loc[(df["Gender"]=="Male") & (df["ApplicantIncome"]>10000)]
df3.head()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 563  LP002795   Male     Yes         3+  Graduate           Yes
# 565  LP002403   Male      No          0  Graduate           Yes
# 566  LP001451   Male     Yes          1  Graduate           Yes
# 567  LP001233   Male     Yes          1  Graduate            No
# 568  LP002541   Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 563            10139                0.0       260.0             360.0
# 565            10416                0.0       187.0             360.0
# 566            10513             3850.0       160.0             180.0
# 567            10750                0.0       312.0             360.0
# 568            10833                0.0       234.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 563             1.0     Semiurban           Y
# 565             0.0         Urban           N
# ...

# %%
df.loc[~((df["Gender"] == "Male") &  (df["ApplicantIncome"]<1500))]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# 9    LP001267  Female     Yes          2      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Group by important

# %%
df=pd.read_csv("Titanic.csv")
df1=pd.read_excel("loandata.xlsx")
df2=pd.read_csv("Sales_Data.csv")

# %%
df.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
df.groupby("Sex")["Age"].sum()
# Out:
# Sex
# female    3844.59
# male      6205.91
# Name: Age, dtype: float64

# %%
df1.head(2)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y

# %%
df1.groupby("Gender")["ApplicantIncome","CoapplicantIncome"].mean()
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/3939529998.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby("Gender")["ApplicantIncome","CoapplicantIncome"].mean()
#         ApplicantIncome  CoapplicantIncome
# Gender
# Female      4643.473214        1108.008929
# Male        5446.460123        1742.932352

# %%
df1.groupby(["Gender","Married"])["LoanAmount"].sum()
# Out:
# Gender  Married
# Female  No          9057.0
#         Yes         4753.0
# Male    No         17011.0
#         Yes        52826.0
# Name: LoanAmount, dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.groupby("Sex")["Age","Fare"].min()
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/2293520399.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Sex")["Age","Fare"].min()
#          Age  Fare
# Sex
# female  0.17  6.95
# male    0.33  0.00

# %% [markdown]
# #  group by with agg{}

# %%
df.groupby("Sex")["Age","Fare"].agg({min,max,np.mean})
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/3115712333.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("Sex")["Age","Fare"].agg({min,max,np.mean})
#               Age                   Fare
#              mean   max   min       mean       max   min
# Sex
# female  30.272362  76.0  0.17  49.747699  512.3292  6.95
# male    30.272732  67.0  0.33  27.527877  262.3750  0.00

# %%
df.groupby('Sex')['Age','Fare'].agg({"Age":[min,max,np.mean,len],"Fare":[max,len]})
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/227068983.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Sex')['Age','Fare'].agg({"Age":[min,max,np.mean,len],"Fare":[max,len]})
#          Age                            Fare
#          min   max       mean  len       max  len
# Sex
# female  0.17  76.0  30.272362  152  512.3292  152
# male    0.33  67.0  30.272732  266  262.3750  266

# %%
df.groupby(['Pclass','Sex'])['Age','Fare'].min()
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/4082343745.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Pclass','Sex'])['Age','Fare'].min()
#                  Age     Fare
# Pclass Sex
# 1      female  18.00  25.7000
#        male     6.00   0.0000
# 2      female   0.92  10.5000
#        male     2.00   9.6875
# 3      female   0.17   6.9500
#        male     0.33   3.1708

# %%
df.groupby(['Pclass','Sex'])['Age','Fare'].agg({min,max,len})
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/1251786243.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Pclass','Sex'])['Age','Fare'].agg({min,max,len})
#                 Age                  Fare
#                 max    min  len       max      min  len
# Pclass Sex
# 1      female  76.0  18.00   50  512.3292  25.7000   50
#        male    67.0   6.00   57  262.3750   0.0000   57
# 2      female  60.0   0.92   30   65.0000  10.5000   30
#        male    63.0   2.00   63   73.5000   9.6875   63
# 3      female  47.0   0.17   72   69.5500   6.9500   72
#        male    60.5   0.33  146   69.5500   3.1708  146

# %%
df.groupby(['Pclass','Sex'])['Age','Fare'].agg({'Age':[min,max,np.mean],'Fare':[min,max,np.mean,sum]})
# Out:
# C:\Users\Afzal\AppData\Local\Temp/ipykernel_10264/2092021969.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Pclass','Sex'])['Age','Fare'].agg({'Age':[min,max,np.mean],'Fare':[min,max,np.mean,sum]})
#                  Age                      Fare                        \
#                  min   max       mean      min       max        mean
# Pclass Sex
# 1      female  18.00  76.0  41.333333  25.7000  512.3292  115.591168
#        male     6.00  67.0  40.520000   0.0000  262.3750   75.586551
# 2      female   0.92  60.0  24.376552  10.5000   65.0000   26.438750
#        male     2.00  63.0  30.940678   9.6875   73.5000   20.184654
# 3      female   0.17  47.0  23.073400   6.9500   69.5500   13.735129
#        male     0.33  60.5  24.525104   3.1708   69.5500   11.826350
#
#
#                      sum
# Pclass Sex
# 1      female  5779.5584
#        male    4308.4334
# ...

# %%
df[df.Sex=='female']['Name'].tolist()
# Out:
# ['Wilkes, Mrs. James (Ellen Needs)',
#  'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#  'Connolly, Miss. Kate',
#  'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#  'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#  'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#  'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#  'Ilmakangas, Miss. Ida Livija',
#  'Assaf Khalil, Mrs. Mariana (Miriam")"',
#  'Flegenheim, Mrs. Alfred (Antoinette)',
#  'Ryerson, Mrs. Arthur Larned (Emily Maria Borie)',
#  'Ostby, Miss. Helene Ragnhild',
#  'Dean, Mrs. Bertram (Eva Georgetta Light)',
#  'Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"',
#  'Roth, Miss. Sarah A',
#  'Cacic, Miss. Manda',
#  'Corbett, Mrs. Walter H (Irene Colvin)',
#  'Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)',
#  'Bucknell, Mrs. William Robert (Emma Eliza Ward)',
#  'Coutts, Mrs. William (Winnie Minnie" Treanor)"',
#  'Hocking, Miss. Ellen Nellie""',
#  'Fortune, Miss. Ethel Flora',
# ...

# %%
dfg=df.groupby(["Pclass","Sex"])["Name"].agg({",".join})
dfg
# Out:
#                                                             join
# Pclass Sex
# 1      female  Snyder, Mrs. John Pillsbury (Nelle Stevenson),...
#        male    Jones, Mr. Charles Cresson,Rothschild, Mr. Mar...
# 2      female  del Carlo, Mrs. Sebastiano (Argenia Genovesi),...
#        male    Myles, Mr. Thomas Francis,Caldwell, Mr. Albert...
# 3      female  Wilkes, Mrs. James (Ellen Needs),Hirvonen, Mrs...
#        male    Kelly, Mr. James,Wirz, Mr. Albert,Svensson, Mr...

# %% [markdown]
# # Crosstab
# The pandas crosstab function builds a cross-tabulation table that can show the frequency with which certain groups of data appear.
#
# Summary tables Suppose we want to see how the observations in our sample are distributed in the context of two variables To do so, we can build a contingency table using the crosstab method:

# %%
pd.crosstab(df.Pclass,[df.Sex,df.Embarked],df.Fare,aggfunc=np.mean)
# Out:
# Sex           female                              male
# Embarked           C          Q           S          C          Q          S
# Pclass
# 1         123.895682  90.000000  105.737110  96.251339        NaN  55.634341
# 2          30.040625        NaN   25.884615  14.451771  11.273950  21.641827
# 3          11.360950   9.051813   16.825610  10.450626   8.931483  12.718872

# %%
df.groupby(['Pclass','Sex','Embarked'])['Fare'].mean()
# Out:
# Pclass  Sex     Embarked
# 1       female  C           123.895682
#                 Q            90.000000
#                 S           105.737110
#         male    C            96.251339
#                 S            55.634341
# 2       female  C            30.040625
#                 S            25.884615
#         male    C            14.451771
#                 Q            11.273950
#                 S            21.641827
# 3       female  C            11.360950
#                 Q             9.051813
#                 S            16.825610
#         male    C            10.450626
#                 Q             8.931483
#                 S            12.718872
# Name: Fare, dtype: float64

# %% [markdown]
# # pivot Table

# %%
df=pd.read_csv("Titanic.csv")
df1=pd.read_csv("Sales_Data.csv")
df2=pd.read_excel("loandata.xlsx")

# %%
df.pivot_table(values="Fare",index="Pclass")
# Out:
#              Fare
# Pclass
# 1       94.280297
# 2       22.202104
# 3       12.459678

# %%
df.pivot_table(values="Fare",index="Pclass",columns="Sex")
# Out:
# Sex         female       male
# Pclass
# 1       115.591168  75.586551
# 2        26.438750  20.184654
# 3        13.735129  11.826350

# %%
df.pivot_table(values="Fare",index="Sex",columns="Pclass")
# Out:
# Pclass           1          2          3
# Sex
# female  115.591168  26.438750  13.735129
# male     75.586551  20.184654  11.826350

# %% [markdown]
# # agg in pivort

# %%
df.pivot_table(values="Age",columns="Sex",index="Pclass",aggfunc="min")
# Out:
# Sex     female  male
# Pclass
# 1        18.00  6.00
# 2         0.92  2.00
# 3         0.17  0.33

# %%
df.pivot_table(values="Age",columns="Sex",index="Pclass",aggfunc=["min","max"])
# Out:
#           min          max
# Sex    female  male female  male
# Pclass
# 1       18.00  6.00   76.0  67.0
# 2        0.92  2.00   60.0  63.0
# 3        0.17  0.33   47.0  60.5

# %%
df2.pivot_table(values=["ApplicantIncome"],index=["Gender","Property_Area"],columns = "Married",aggfunc='count')
# Out:
#                      ApplicantIncome
# Married                           No  Yes
# Gender Property_Area
# Female Rural                      19    5
#        Semiurban                  34   20
#        Urban                      27    6
# Male   Rural                      44  107
#        Semiurban                  44  127
#        Urban                      42  123

# %%
df2.pivot_table(index='Property_Area',columns=['Married','Gender'],values='ApplicantIncome',aggfunc='mean')
# Out:
# Married                 No                       Yes
# Gender              Female         Male       Female         Male
# Property_Area
# Rural          4135.421053  5317.954545  5181.600000  5844.813084
# Semiurban      4965.588235  5421.545455  4221.150000  5414.559055
# Urban          4181.481481  4956.214286  6564.666667  5374.000000

# %% [markdown]
# ### another method

# %%
pd.pivot_table(df,values="Age",columns="Sex",index="Pclass",aggfunc=["min","max"])
# Out:
#           min          max
# Sex    female  male female  male
# Pclass
# 1       18.00  6.00   76.0  67.0
# 2        0.92  2.00   60.0  63.0
# 3        0.17  0.33   47.0  60.5

# %% [markdown]
# # concat

# %%
df1=pd.DataFrame({"Name":["Afzal","Ather","Arman","MunazirBhai"],"Age":[22,14,67,34],"Gender":["M","M","F","F"]})
df2 = pd.DataFrame({'Name': ['Akhil', 'Asha', 'Preeti'],'Age': ['31', '22', '23'],'Gender': ['M', 'F', 'F']})

# %%
pd.DataFrame(df1)
# Out:
#           Name  Age Gender
# 0        Afzal   22      M
# 1        Ather   14      M
# 2        Arman   67      F
# 3  MunazirBhai   34      F

# %%
pd.DataFrame(df2)
# Out:
#      Name Age Gender
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
df=pd.concat([df1,df2]) # default axis=0
df
# Out:
#           Name Age Gender
# 0        Afzal  22      M
# 1        Ather  14      M
# 2        Arman  67      F
# 3  MunazirBhai  34      F
# 0        Akhil  31      M
# 1         Asha  22      F
# 2       Preeti  23      F

# %%
df.reset_index(drop=True)
# Out:
#           Name Age Gender
# 0        Afzal  22      M
# 1        Ather  14      M
# 2        Arman  67      F
# 3  MunazirBhai  34      F
# 4        Akhil  31      M
# 5         Asha  22      F
# 6       Preeti  23      F

# %%
df=pd.concat([df1,df2],ignore_index=True)
df
# Out:
#           Name Age Gender
# 0        Afzal  22      M
# 1        Ather  14      M
# 2        Arman  67      F
# 3  MunazirBhai  34      F
# 4        Akhil  31      M
# 5         Asha  22      F
# 6       Preeti  23      F

# %%
df=pd.concat([df1,df2],axis=1) # default axis=0
df
# Out:
#           Name Age Gender    Name  Age Gender
# 0        Afzal  22      M   Akhil   31      M
# 1        Ather  14      M    Asha   22      F
# 2        Arman  67      F  Preeti   23      F
# 3  MunazirBhai  34      F     NaN  NaN    NaN

# %% [markdown]
# # APPEND

# %%
df_res=df1.append(df2)
df_res
# Out:
#           Name Age Gender
# 0        Afzal  22      M
# 1        Ather  14      M
# 2        Arman  67      F
# 3  MunazirBhai  34      F
# 0        Akhil  31      M
# 1         Asha  22      F
# 2       Preeti  23      F

# %% [markdown]
# # how to reset index

# %%
def_res=df1.append(df2,ignore_index=True)
def_res
# Out:
#           Name Age Gender
# 0        Afzal  22      M
# 1        Ather  14      M
# 2        Arman  67      F
# 3  MunazirBhai  34      F
# 4        Akhil  31      M
# 5         Asha  22      F
# 6       Preeti  23      F

# %% [markdown]
# # Merge DataFrames

# %% [markdown]
# # join

# %%
df1=pd.DataFrame({'id':[1,2,3,4],
                 'name':['a','b','c','d']})

df2=pd.DataFrame({'id':[1,2,3,5],
                 'class':['first','fourth','fifth','tenth']})

# %%
df1
# Out:
#    id name
# 0   1    a
# 1   2    b
# 2   3    c
# 3   4    d

# %%
df2
# Out:
#    id   class
# 0   1   first
# 1   2  fourth
# 2   3   fifth
# 3   5   tenth

# %%
# inner Join

# %%
pd.merge(df1,df2,on="id",how="inner")
# Out:
#    id name   class
# 0   1    a   first
# 1   2    b  fourth
# 2   3    c   fifth

# %%
#lef join

# %%
pd.merge(df1,df2,on='id',how='left')
# Out:
#    id name   class
# 0   1    a   first
# 1   2    b  fourth
# 2   3    c   fifth
# 3   4    d     NaN

# %%
# right join

# %%
pd.merge(df1,df2,on='id',how='right')
# Out:
#    id name   class
# 0   1    a   first
# 1   2    b  fourth
# 2   3    c   fifth
# 3   5  NaN   tenth

# %%
# outer join

# %%
pd.merge(df1,df2,on='id',how="outer")
# Out:
#    id name   class
# 0   1    a   first
# 1   2    b  fourth
# 2   3    c   fifth
# 3   4    d     NaN
# 4   5  NaN   tenth

# %% [markdown]
# # join

# %%
l = pd.DataFrame(
    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"]
)
l
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
r= pd.DataFrame(
    {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"]
)
r
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
l.join(r,how='inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
l.join(r,how='left')
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
l.join(r,how='right')
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %%
l.join(r,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
df1=pd.DataFrame({'id':[1,2,3,4],
                 'name':['a','b','c','d']})

df2=pd.DataFrame({'label':[1,2,3,5],
                 'class':['first','fourth','fifth','tenth']})

# %%
pd.merge(df1,df2,left_on='id',right_on='label',how="inner") # common col but different names
# Out:
#    id name  label   class
# 0   1    a      1   first
# 1   2    b      2  fourth
# 2   3    c      3   fifth

# %% [markdown]
# # missing values

# %%
df=pd.read_excel("loandata.xlsx")

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# #### When you have outliers , median is to be used instead of mean for filling missing values

# %%
dict1 = {'First Score':[100, 90, np.nan, 95], 
        'Second Score': [30, 45, 56, np.nan], 
        'Third Score':[np.nan, 40, 80, 98]} 
  
df = pd.DataFrame(dict1) 
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %% [markdown]
# # fillna and dropna

# %%
df.fillna(method='pad') #forward fill
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
df.fillna(method='bfill') #forward fill
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df.fillna(30)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         30.0
# 1         90.0          45.0         40.0
# 2         30.0          56.0         80.0
# 3         95.0          30.0         98.0

# %%
df["First Score"]=df["First Score"].fillna(30)

# %%
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         30.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df["Third Score"]=df["Third Score"].fillna(np.median(df["Third Score"].dropna()))
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         80.0
# 1         90.0          45.0         40.0
# 2         30.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df=pd.read_excel("loandata.xlsx")

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
df.dropna(how="any")# delete rows that has atleast one cell NaN
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001722    Male     Yes          0  Graduate            No
# 3    LP002603  Female      No          0  Graduate            No
# 5    LP001259    Male     Yes          1  Graduate           Yes
# 6    LP002345    Male     Yes          0  Graduate            No
# 8    LP001030    Male     Yes          2  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 607  LP001637    Male     Yes          1  Graduate            No
# 608  LP002422    Male      No          1  Graduate            No
# 609  LP001640    Male     Yes          0  Graduate           Yes
# 610  LP001536    Male     Yes         3+  Graduate            No
# 613  LP002317    Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# ...

# %%
df.dropna(how='all')
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.dropna(how='any',axis=1)
# Out:
#       Loan_ID     Education  ApplicantIncome  CoapplicantIncome Property_Area  \
# 0    LP001722      Graduate              150             1800.0         Rural
# 1    LP002502  Not Graduate              210             2917.0     Semiurban
# 2    LP002949      Graduate              416            41667.0         Urban
# 3    LP002603      Graduate              645             3683.0         Rural
# 4    LP001644      Graduate              674             5296.0         Rural
# ..        ...           ...              ...                ...           ...
# 609  LP001640      Graduate            39147             4750.0     Semiurban
# 610  LP001536      Graduate            39999                0.0     Semiurban
# 611  LP001585      Graduate            51763                0.0         Urban
# 612  LP002101      Graduate            63337                0.0         Urban
# 613  LP002317      Graduate            81000                0.0         Rural
#
#     Loan_Status
# ...

# %%
df2 = df[df['Loan_Status'].notna()]# will run this tommororw
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Replace Null Values (np.nan) with mean

# %%
df=pd.read_excel("loandata.xlsx")

# %%
df["ApplicantIncome"].mean()
# Out:
# 5403.459283387622

# %%
df["Credit_History"].fillna(5403.459)
# Out:
# 0         1.000
# 1         1.000
# 2      5403.459
# 3         1.000
# 4         1.000
#          ...
# 609       1.000
# 610       0.000
# 611       1.000
# 612       1.000
# 613       0.000
# Name: Credit_History, Length: 614, dtype: float64

# %%
df["Credit_History"].fillna(df["Credit_History"].mean())
# Out:
# 0      1.000000
# 1      1.000000
# 2      0.842199
# 3      1.000000
# 4      1.000000
#          ...
# 609    1.000000
# 610    0.000000
# 611    1.000000
# 612    1.000000
# 613    0.000000
# Name: Credit_History, Length: 614, dtype: float64

# %% [markdown]
# #### replace the nan value

# %%
df["Gender"]=df["Gender"].replace(np.nan,df["ApplicantIncome"].mean())

# %%
df
# Out:
#       Loan_ID       Gender Married Dependents     Education Self_Employed  \
# 0    LP001722         Male     Yes          0      Graduate            No
# 1    LP002502       Female     Yes          2  Not Graduate           NaN
# 2    LP002949       Female      No         3+      Graduate           NaN
# 3    LP002603       Female      No          0      Graduate            No
# 4    LP001644  5403.459283     Yes          0      Graduate           Yes
# ..        ...          ...     ...        ...           ...           ...
# 609  LP001640         Male     Yes          0      Graduate           Yes
# 610  LP001536         Male     Yes         3+      Graduate            No
# 611  LP001585  5403.459283     Yes         3+      Graduate            No
# 612  LP002101         Male     Yes          0      Graduate           NaN
# 613  LP002317         Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.fillna(value=5)
# Out:
#       Loan_ID       Gender Married Dependents     Education Self_Employed  \
# 0    LP001722         Male     Yes          0      Graduate            No
# 1    LP002502       Female     Yes          2  Not Graduate             5
# 2    LP002949       Female      No         3+      Graduate             5
# 3    LP002603       Female      No          0      Graduate            No
# 4    LP001644  5403.459283     Yes          0      Graduate           Yes
# ..        ...          ...     ...        ...           ...           ...
# 609  LP001640         Male     Yes          0      Graduate           Yes
# 610  LP001536         Male     Yes         3+      Graduate            No
# 611  LP001585  5403.459283     Yes         3+      Graduate            No
# 612  LP002101         Male     Yes          0      Graduate             5
# 613  LP002317         Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Gender'].mode()
# Out:
# 0    Male
# dtype: object

# %%
df['Gender'].fillna(df['Gender'].mode()[0])
# Out:
# 0             Male
# 1           Female
# 2           Female
# 3           Female
# 4      5403.459283
#           ...
# 609           Male
# 610           Male
# 611    5403.459283
# 612           Male
# 613           Male
# Name: Gender, Length: 614, dtype: object

# %% [markdown]
# # duplicates

# %%
# Creating dataframe using dictionary
dict1 = {'Gender': ["Male", "Female", "Male", "Female","Male"], 
        'Married':["Yes", "No","No", "No","Yes"],
       'Loan_Status':["Yes", "No", "No", "No","Yes"]} 
  
df = pd.DataFrame(dict1)
df
# Out:
#    Gender Married Loan_Status
# 0    Male     Yes         Yes
# 1  Female      No          No
# 2    Male      No          No
# 3  Female      No          No
# 4    Male     Yes         Yes

# %%
df.drop_duplicates()# default is keep = first
# Out:
#    Gender Married Loan_Status
# 0    Male     Yes         Yes
# 1  Female      No          No
# 2    Male      No          No

# %%
df.drop_duplicates(keep='first')# default is keep = first
# Out:
#    Gender Married Loan_Status
# 0    Male     Yes         Yes
# 1  Female      No          No
# 2    Male      No          No

# %%
df.drop_duplicates(keep='last')# default is keep = first
# Out:
#    Gender Married Loan_Status
# 2    Male      No          No
# 3  Female      No          No
# 4    Male     Yes         Yes

# %%
df.drop_duplicates(keep=False)# default is keep = first
# Out:
#   Gender Married Loan_Status
# 2   Male      No          No

# %%
df1=df.drop_duplicates(keep='last',subset=['Married'])# default is keep = first

# %%
df1
# Out:
#    Gender Married Loan_Status
# 3  Female      No          No
# 4    Male     Yes         Yes

# %%
df1.reset_index()
# Out:
#    index  Gender Married Loan_Status
# 0      3  Female      No          No
# 1      4    Male     Yes         Yes

# %%
df1.reset_index(drop=True)
# Out:
#    Gender Married Loan_Status
# 0  Female      No          No
# 1    Male     Yes         Yes

# %% [markdown]
# # date and time plzz see pandas 7 file

# %% [markdown]
# # unique and nunique

# %%
df=pd.read_excel("loandata.xlsx")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df["Gender"].nunique()
# Out:
# 2

# %%
df_titanic = pd.read_csv("Titanic.csv")
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_titanic["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # isin()

# %%
# get records whose age is 40,42,44,46,48,50 (like a filter operator)

df_titanic[df_titanic["Age"].isin([40,42,44,46,48,50])]

#df_titanic[(df_titanic['Age']==40) | df_titanic['Age']==42) |................df_titanic['Age']==50) ]
# Out:
#      PassengerId  Pclass                                               Name  \
# 11           903       1                         Jones, Mr. Charles Cresson
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 25           917       3                            Robins, Mr. Alexander A
# 30           922       2                       Louch, Mr. Charles Alexander
# 128         1020       2                               Bowenur, Mr. Solomon
# 139         1031       3                     Goodwin, Mr. Charles Frederick
# 144         1036       1  Lindeberg-Lind, Mr. Erik Gustaf (Mr Edward Lin...
# 158         1050       1                           Borebank, Mr. John James
# 166         1058       1                                 Brandeis, Mr. Emil
# 174         1066       3         Asplund, Mr. Carl Oscar Vilhelm Gustafsson
# 185         1077       2                          Maybery, Mr. Frank Hubert
# ...

# %% [markdown]
# # QUERY

# %%
df_titanic.query("Age >40 and Age <50") # engllish sent based filter condition
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 11           903       1                         Jones, Mr. Charles Cresson
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 28           920       1                            Brady, Mr. John Bertram
# 42           934       3                              Goldsmith, Mr. Nathan
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# 67           959       1                     Moore, Mr. Clarence Bloomfield
# 82           974       1                             Case, Mr. Howard Brown
# ...

# %% [markdown]
# # sort and nlargest,nsmallest

# %%
df_titanic.sort_values("Age",ascending=False)
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df_titanic["Age"].nlargest(5)
# Out:
# 96     76.0
# 81     67.0
# 179    64.0
# 236    64.0
# 305    64.0
# Name: Age, dtype: float64

# %%
df_titanic['Age'].nsmallest(5)
# Out:
# 354    0.17
# 201    0.33
# 281    0.75
# 307    0.83
# 250    0.92
# Name: Age, dtype: float64

# %%
df_titanic["Name"].loc[0:9]
# Out:
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                      Svensson, Mr. Johan Cervin
# 6                            Connolly, Miss. Kate
# 7                    Caldwell, Mr. Albert Francis
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9                         Davies, Mr. John Samuel
# Name: Name, dtype: object

# %%
df_titanic["small"]=df_titanic["Name"].str.lower()
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # map

# %%
new={"male":0,"female":1}

# %%
df_titanic["Gender"]=df_titanic["Sex"].map(new)
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # apply

# %%
def discount_fun(x):
    if x["Age"]>60 and x["Sex"]=="female":
        return x["Fare"]-5
    else:
        return x['Fare']

# %%
df_titanic['discount_fare']=df_titanic.apply(discount_fun,axis=1)

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  \
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
#
#                                           small  Gender  discount_fare
# 0                              kelly, mr. james       0         7.8292
# ...

# %%
def discount_fun(x):
    if x["Age"]>60 :
        return 'Old'
    else:
        return 'Young'

# %%
df_titanic["newage"]=df_titanic.apply(discount_fun,axis=1)

# %%
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # usefull

# %%
a=60

# %%
~a
# Out:
# -61

# %% [markdown]
# - we have a range of numbers and we want to see only one number

# %%
num = int(input())
var = int(input("Enter the number you want to see the output : "))

for i in range(1,num+1):
    if i==var:
        print(i)
# Out:
# 10
# Enter the number you want to see the output : 5
# 5

# %%
4

# %%
n=eval(input())
# Out:
# [1,2,3,4,5]

# %%
print(n[-1])
# Out:
# 5
